# %%
import openai
import pandas as pd
import re
import requests
import time
import random
import json
import os
import tweepy

# Set the number of iterations after successfully logging in
num_iterations = 60

# Your OpenAI API key
openai.api_key = "sk-0cOixdOplWkP7OCknebwT3BlbkFJz5O3GHds9BElvZtgdhasgsdi"

# Your Google Custom Search API key and engine ID
api_key = "AIzaSyCZNWCJYnyzLId07ZBM-USrdspd1lRArqI"
custom_search_engine_id = "82390688dsad2d4c24"

# Your Twitter API tokens
Bearer_token = "AAAAAAAAAAAAAAAAAAAAAPCRqwEAAAAA7XjFaE64Kh8Xytusau6MdUrWb%2B%2FRs%3DmCPNjzet3s6SEHqOeqPHT3GcE0yoJpzjcJi1r7Q83ybPgGMEFk"
consumer_key = "qd6L5OjQZ8D4Fph1Pv3vieuyas99"
consumer_secret = "fEap3xzLZsvcnt01tZ5l2jygt1zAwfn5yRIXJSZNb11bHuys7N"
access_token = "1721119543437713408-DDPUhmwdfBQDR9cWU0sHjEy8SjNasq"
access_token_secret = "5Wgp5W6E93Cq2XneVhddssaOFd1Zwh5lLoOb5s7oESOAOqT"

# V1 Twitter API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# V2 Twitter API Authentication
client = tweepy.Client(
    Bearer_token,
    consumer_key,
    consumer_secret,
    access_token,
    access_token_secret,
    wait_on_rate_limit=True,
)

def generate_random_item():
    github_url = 'https://github.com/AkelloVJ/R-programming/raw/main/Topics_on_the_academic_arena.csv'
    Topics = pd.read_csv(github_url, encoding='latin1')
    column_name = 'Topics'
    return Topics[column_name].sample().values[0]

def generate_questions(prompt):
    return openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt},
        ]
    ).choices[0].message['content'].strip().split("\n")

def generate_essay(prompt):
    essay_prompt = f"write a short one sentence tweet on the selected item:\n\n{prompt}"
    return openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        max_tokens=29,
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": essay_prompt},
        ]
    ).choices[0].message['content'].strip() + "\n\nhomeworkhelp.net \n\nhobi caturday burars vernon odegaard saka"
       
def download_and_tweet_image(search_query):
    url = f"https://www.googleapis.com/customsearch/v1?key={api_key}&cx={custom_search_engine_id}&q={search_query}&searchType=image"
    response = requests.get(url)
    data = response.json()

    if "items" in data:
        first_image = data["items"][0]
        image_url = first_image["link"]
        response = requests.get(image_url)

        if response.status_code == 200:
            os.makedirs("downloaded_images", exist_ok=True)
            with open("downloaded_images/image.jpg", "wb") as f:
                f.write(response.content)
            print("Image downloaded and saved as 'image.jpg'.")

            media = api.media_upload("downloaded_images/image.jpg")
            media_id = media.media_id_string

            text = generate_essay(search_query)
            client.create_tweet(text=text, media_ids=[media_id])
            print("Tweeted with image!")
        else:
            print("Failed to download the image. Tweeting with text only.")

            text = generate_essay(search_query)
            client.create_tweet(text=text)
            print("Tweeted without image.")
    else:
        print("No images found for the search query.")

# Main loop
for _ in range(num_iterations):
    try:
        random_item = generate_random_item()
        print("Randomly selected item:", random_item)

        prompt = f"Generate a list of interesting concepts as to how python programming can be used to increase the efficiency of the domain: {random_item}."
        questions = generate_questions(prompt)
        selected_question = random.choice(questions)
        selected_question1 = re.sub(r'^\d+\.\s*', '', selected_question)

        download_and_tweet_image(random_item)

        time.sleep(random.randint(300, 450))  # Sleep for 5 to 10 minutes

    except Exception as e:
        print(f"An error occurred: {e}. Restarting the iteration.")
        time.sleep(60)  # Sleep for 1 minute before restarting the iteration
# Out:
# Randomly selected item: Distance education
# Image downloaded and saved as 'image.jpg'.
# Tweeted with image!
# Randomly selected item: Animation
# Image downloaded and saved as 'image.jpg'.
# Tweeted with image!
# Randomly selected item: Probability (outline)
# Image downloaded and saved as 'image.jpg'.
# Tweeted with image!
# Randomly selected item: Chemical physics
# Image downloaded and saved as 'image.jpg'.
# Tweeted with image!
# Randomly selected item: Astrochemistry
# Image downloaded and saved as 'image.jpg'.
# Tweeted with image!
# Randomly selected item: Submillimetre astronomy
# Failed to download the image. Tweeting with text only.
# Tweeted without image.
# Randomly selected item: Sex education
# Image downloaded and saved as 'image.jpg'.
# Tweeted with image!
# Randomly selected item: Ethnochoreology
# Image downloaded and saved as 'image.jpg'.
# Tweeted with image!
# Randomly selected item: Arms race
# Image downloaded and saved as 'image.jpg'.
# Tweeted with image!
# ...
